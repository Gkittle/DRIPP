# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.figure(figsize=(10,10))
#list_fail = [0,1,17]
list_fail = []
for i in range(14):
    if i in list_fail:
        continue
    list = []
    with open(f"/home/gkittles/SB_DRIPP_Results/4_3_25_Convergence/scenario_1/slurm-62577378_{i+1}.out") as f:
        for line in f:
            ilist = [elt.strip() for elt in line.split('; ')]
            list.append(ilist)
    nfe = []
    cost = []
    for val in list:
        nfe.append(int(val[0].split(" ")[1]))
        cost.append(float(val[2].split(" ")[0]))
    color = plt.cm.cool(i/14)
    plt.plot(nfe,cost, label = f"{i}", color=color);
plt.legend();
plt.xlabel('NFE');
plt.ylabel('System Cost');

# %%
list = []
with open(f"/home/gkittles/SB_DRIPP_Results/4_3_25_Convergence/scenario_1/slurm-62577378_12.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
print(cost)
plt.plot(nfe,cost);
# Out:
# [2.5471486660408513, 2.5471486660408513, 2.5471486660408513, 1.9771943548091113, 1.9771943548091113, 1.9771943548091113, 1.9771943548091113, 1.9771943548091113, 1.9724999542201076, 1.9724999542201076, 1.9724999542201076, 1.9724999542201076, 1.9724999542201076, 1.9724999542201076, 1.9311369226422443, 1.9311369226422443, 1.2962674568966455, 1.2962674568966455, 1.2962674568966455, 1.2561229768240254, 1.1780808739311095, 1.155513327932447, 1.155513327932447, 1.1167077773874237, 1.1167077773874237, 1.0976950997820905, 1.0976950997820905, 1.0976950997820905, 1.0976950997820905, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.08941606388467, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0723824440635576, 1.0706192673891533, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.065002783584677, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0644239128522122, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.0635253548467491, 1.06352535484674 ...

# %%
list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026379.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026410.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026418.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026421.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

#plt.ylim(0,1.3);
