# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.figure(figsize=(10,10))
#list_fail = [0,1,17]
list_fail = []
for i in range(14):
    if i in list_fail:
        continue
    list = []
    with open(f"/home/gkittles/SB_DRIPP_Results/5_2_25_Capped_Storage/slurm-64393947_{i+1}.out") as f:
        for line in f:
            ilist = [elt.strip() for elt in line.split('; ')]
            list.append(ilist)
    nfe = []
    cost = []
    for val in list:
        nfe.append(int(val[0].split(" ")[1]))
        cost.append(float(val[2].split(" ")[0]))
    color = plt.cm.cool(i/14)
    plt.plot(nfe,cost, label = f"{i}", color=color);
plt.legend();
plt.xlabel('NFE');
plt.ylabel('System Cost');

# %%
list = []
with open(f"/home/gkittles/SB_DRIPP_Results/4_3_25_Convergence/scenario_1/slurm-62577378_12.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
    plt.plot(nfe,cost);

# %%
list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026379.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026410.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026418.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

list = []
with open(f"/home/gkittles/SB_DRIPP_Results/3_25_25_Convergence/slurm-62026421.out") as f:
    for line in f:
        ilist = [elt.strip() for elt in line.split('; ')]
        list.append(ilist)
nfe = []
cost = []
for val in list:
    nfe.append(int(val[0].split(" ")[1]))
    cost.append(float(val[2].split(" ")[0]))
plt.plot(nfe,cost);

#plt.ylim(0,1.3);
