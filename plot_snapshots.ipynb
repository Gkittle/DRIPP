# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
plt.figure(figsize=(10,10))
list_fail = [0,1,17]
for i in range(40):
    if i in list_fail:
        continue
    list = []
    with open(f"/home/gkittles/SB_DRIPP_Results/3_06_25_Cost_Curtailment/slurm-60906955_{i+1}.out") as f:
        for line in f:
            ilist = [elt.strip() for elt in line.split('; ')]
            list.append(ilist)
    nfe = []
    cost = []
    for val in list:
        nfe.append(int(val[0].split(" ")[1]))
        cost.append(float(val[2].split(" ")[0]))
    color = plt.cm.cool(i/40)
    plt.plot(nfe,cost, label = f"{i}", color=color);
#plt.legend();
