# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
for i in range(10):
    list = []
    with open(f"/home/gkittles/SB_DRIPP_Results/3_05_25_Percentage_Follow/slurm-60831837_{i+1}.out") as f:
        for line in f:
            ilist = [elt.strip() for elt in line.split('; ')]
            list.append(ilist)
    nfe = []
    cost = []
    for val in list:
        nfe.append(int(val[0].split(" ")[1]))
        cost.append(float(val[2].split(" ")[0]))
    plt.plot(nfe,cost, label = f"{i}");
plt.legend();
